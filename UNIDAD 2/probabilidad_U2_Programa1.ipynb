# %% [markdown]
# <a href="https://colab.research.google.com/github/25040999-cmd/Probabilidad-y-estadistica-/blob/main/UNIDAD%202/probabilidad_U2_Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # probabilidad y estadística
#
# ## Unidad 2
#
# ### facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Juan Antonio Alvarado Barrón
#
# ### **Programa 1: **

# %%
import math as mt #Para utilizar factorial
from itertools import combinations
from itertools import combinations_with_replacement

# %%
nombres = [ "Oscar", "Paco", "Paty", "Laura", "Rubén", "Luis", "Juan", "Danny"  ]
n = len(nombres)
r = 2 # Cómo agrupar?
Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n - r))
print("Existen", Cn, "posibles combinaciones sin repeticion del total de", n, "nombres", "en grupos de ", r, "en", r)

print("aquí las combinaciones")
combinaciones_nombres = list(combinations(nombres, r))

#Imprime las combinaciones
for combinacion in combinaciones_nombres:
    print(combinacion)
# Out:
# Existen 28.0 posibles combinaciones sin repeticion del total de 8 nombres en grupos de  2 en 2
# aquí las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Paty')
# ('Oscar', 'Laura')
# ('Oscar', 'Rubén')
# ('Oscar', 'Luis')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Paty')
# ('Paco', 'Laura')
# ('Paco', 'Rubén')
# ('Paco', 'Luis')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Paty', 'Laura')
# ('Paty', 'Rubén')
# ('Paty', 'Luis')
# ('Paty', 'Juan')
# ('Paty', 'Danny')
# ('Laura', 'Rubén')
# ('Laura', 'Luis')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Rubén', 'Luis')
# ('Rubén', 'Juan')
# ('Rubén', 'Danny')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Juan', 'Danny')
